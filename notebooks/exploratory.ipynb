# %%
import kagglehub
import pandas as pd
import os

# 🔽 Pobranie danych
path = kagglehub.dataset_download("jashanjeetsinghhh/songs-dataset")

music_csv=os.path.join(path,"Music.csv")
data_read=pd.read_csv(music_csv)
# Usunięcie NaNów
cleaned_data=data_read.dropna()
data_read
# Out:
#                                           name          artist  \
# 0                       Mood (feat. iann dior)        24kGoldn
# 1                              Blinding Lights      The Weeknd
# 2                                     Dynamite             BTS
# 3                 ROCKSTAR (feat. Roddy Ricch)          DaBaby
# 4      For The Night (feat. Lil Baby & DaBaby)       Pop Smoke
# ...                                        ...             ...
# 65790                    History Lesson Part 2       Minutemen
# 65791                             Call My Name  Michael Bolton
# 65792              Welcome To The Working Week  Elvis Costello
# 65793                                 Patricia      Art Pepper
# 65794                      For Once In My Life   Frank Sinatra
#
#                    spotify_id  \
# 0      3tjFYV6RSFtuktYl3ZtYcq
# 1      0VjIjW4GlUZAMYd2vXMi3b
# 2      0t1kP63rueHleOhQkYSXFY
# 3      7ytR5pFWmSjzHJIeQkgog4
# 4      0PvFJmanyNQMseIFrU708S
# ...
